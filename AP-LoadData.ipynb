# %%
from files import examples
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
from sklearn.datasets import load_diabetes

# %% [markdown]
# # 📘 Forelæsning: At læse data fra filer i Python
#
# > *Fra tekstfil til objekter*

# %% [markdown]
# # Let us load data from a file
#
# - Quick recap
# - What is data
# - Classes
# - Objects
# - attributes and methods
# - Encapsulation

# %% [markdown]
# # Exercises Recap

# %% [markdown]
# ## Exercise: Sensor → Patient
#
# **Det ved du**
#
# * Objekter kan sendes som argumenter
# * Metoder kan kalde metoder på andre objekter
#
# **Problemformulering**
# Patientens puls skal komme fra en sensor – ikke fra manuel indtastning.
#
# **Det skal du gøre**
# * Lav et program `my_patient_sensor.py`
# * Lav en klasse `HeartRateSensor`
# * Giv den en metode `measure()` som returnerer en puls
# * Opdater patientens puls via sensoren
# * Sørg for, at patienten ikke selv “finder på” værdier
#
#
# > Den Laver vi lige i vs code!

# %% [markdown]
# # What is Data?

# %% [markdown]
# ## Basic data

# %%
examples.df_1(N=3)
# Out:
#    hej
# 0   32
# 1   97
# 2   81

# %% [markdown]
# ## Game Characters

# %%
examples.df_2(N=3)
# Out:
#           Unit Name      Type  Normal Attack Power  Max Health  \
# 0        Child Mech     Naval                  293        1554
# 1  Institution Mech  Infantry                   21         283
# 2         Fill Mech  Aircraft                  134         869
#
#    Ultimate Attack Power
# 0                   1040
# 1                     34
# 2                    407

# %% [markdown]
# ## Patient Data

# %%
examples.df_3(N=3)
# Out:
#           Name         DOB  Systolic_BP  Diastolic_BP  EF_Percent
# 0   Lisa Rivas  1941-09-26          111           109          40
# 1  Jessica Ray  1942-10-13          149            84          27
# 2   Diane Gray  1946-01-13          109            62          49

# %% [markdown]
# # Hvorfor arbejde med filer?
#
# I virkelige projekter:
# * Data kommer ikke fra `print()`
# * Data kommer ikke fra hardkodede tal
# * Data kommer fra:
#   * Måleudstyr
#   * Logfiler
#   * Eksport fra software
#   * Eksperimenter
#
# **Filer er forbindelsen til virkeligheden**

# %% [markdown]
# ## Hvad er en fil (konceptuelt)?
#
# En fil er:
# * En sekvens af tegn (tekst)
# * Gemt på disk
# * Kan læses fra start til slut
#
# I Python:
# > En fil behandles som en **strøm af tekst**

# %% [markdown]
# # **Læs data fra fil**
#
# *   **CSV-filer (Comma-Separated Values)**
#     *   Meget simpelt og udbredt format til dataudveksling
#     *   Almindelig tekstfil – kan åbnes i editorer som `.txt`, `.py`, osv.
# *   **Hvorfor bruge CSV?**
#     *   Let at læse og skrive med standardværktøjer
#     *   Understøttes af næsten alle programmeringssprog og analyseværktøjer
# *   **Når data er indlæst i hukommelsen:**
#     *   Kan behandles som normale Python-strukturer (lister, arrays)
#     *   Mulighed for analyse, beregninger og visualisering

# %% [markdown]
# ## Den simpleste tekstfil
#
# Eksempel (`data.txt`):
#
# ```
# 72
# 75
# 78
# 80
# ```
#
# Dette kunne være:
#
# * Pulsmålinger
# * Temperatur
# * Signaludsnit

# %% [markdown]
# # Fra fil til python objekt

# %% [markdown]
# ## Trin 1: Åbn en fil
#
# > ```python
# > f = open("data.txt", "r")
# > ```
#
# * `"data.txt"` → filnavn
# * `"r"` → read (læsning)
#
# Filen skal ligge i samme mappe som `.py`-filen

# %% [markdown]
# ___
# ## Trin 2: Læs indhold
# > ```python
# > content = f.read()
# > print(content)
# > ```
#
# * Hele filen læses som **én stor tekst**
# * Linjeskift er `\n`
# ```

# %% [markdown]
# ___
#
# ## Trin 3: Luk filen
#
# > ```python
# > f.close()
# > ```
#
# Vigtigt:
#
# * Åbne filer bruger ressourcer
# * Luk altid filen igen

# %% [markdown]
# ___
#
# ## Samlet eksempel
#
# > ```python
# > f = open("data.txt", "r")
# > content = f.read()
# > f.close()
# > print(content)
# > ```
#
# Dette virker — men kan gøres bedre.

# %% [markdown]
# ___
#
# ## Den anbefalede måde: `with`
#
# > ```python
# > with open("data.txt", "r") as f:
# >     content = f.read()
# >
# > print(content)
# > ```
#
# Fordel:
#
# * Filen lukkes automatisk
# * Færre fejl
#
# **Brug altid `with`**

# %% [markdown]
# ___
#
# ## Fra tekst til linjer
#
# Ofte vil vi arbejde **linje for linje**.
#
# > ```python
# > with open("data.txt", "r") as f:
# >     lines = f.readlines()
# > ```
#
# `lines` er nu en **liste af strenge**.

# %% [markdown]
# ___
#
# ## Hvad er der i `lines`?

# %%
with open("files/data.txt", "r") as f:
    lines = f.readlines()
    print(lines)

# %% [markdown]
# Bemærk:
#
# * Alt er tekst
# * `\n` betyder linjeskift

# %% [markdown]
# ## Fjern linjeskift
#
# > ```python
# > clean_lines = []
# > for line in lines:
# >    clean_lines.append(line.strip())
# > ```
#
# `strip()`:
# * Fjerner mellemrum
# * Fjerner `\n`

# %% [markdown]
# ___
#
# ## Fra tekst til tal
#
# ```python
# values = []
#
# for line in clean_lines:
#     values.append(int(line))
# ```
#
# Nu har vi:
#
# ```python
# [72, 75, 78, 80]
# ```

# %% [markdown]
# ___
#
# ## Samlet pipeline (meget vigtig slide)
#
# > ```python
# > values = []
# > with open("data.txt", "r") as f:
# >     for line in f:
# >         values.append(int(line.strip()))
# > print(values)
# > ```
#
# Dette mønster ser du igen og igen i Python.

# %% [markdown]
# ## Sammenligning med C (mental bro)
#
# I C:
#
# * Åbn fil
# * Læs linje
# * Parse tekst
# * Luk fil
#
# I Python:
#
# * Samme idé
# * Færre linjer
# * Mindre støj
#
# Men:
#
# > **Du skal stadig forstå hvert trin**

# %% [markdown]
# ___
#
# ## Typiske fejl (vis dem eksplicit)
#
# * Forkert filnavn
# * Filen ligger i forkert mappe
# * Glemmer `strip()`
# * Glemmer at konvertere til `int` eller `float`
#
# Disse fejl er **normale**

# %% [markdown]
# ## Example of fileloading

# %% [markdown]
# > * Den første linje indeholder måske data information
# > * Data er ikke nødvendigvis et heltal, men kan være float

# %%
filename = "files/data_1_rows.csv"
data = []
with open(filename, "r") as f:
    header = f.readline().strip()

    for line in f:
        data.append(float(line.strip()))

print(f"Loaded {len(data)} rows of data")
print(f"The first row often contain the column names, which in this case are {header=}")
N = 5
print(f"First {N} rows")
for i, row in enumerate(data):
    if i > N:
        break
    print(f" {i}: {row:.3f}")
# Out:
# We loaded 12883 rows of data into the variable data
# The first row often contain the column names, which in this case are header='ecg'
# First 5 rows
#  0: 0.037
#  1: -0.005
#  2: -0.026
#  3: -0.090
#  4: 0.033
#  5: 0.023

# %% [markdown]
# - Uses file open
# - Uses file close
#     - If anything happens, i.e. program crashes, we still have to close the file (This sucks, and is difficult)

# %% [markdown]
# ### **Brug OOP til at læse data**
#
# *   Den nemmeste måde at indlæse data på er ofte at bruge et bibliotek med indbyggede funktioner og metoder.
#     *   Dette reducerer kompleksiteten og sparer tid.
# *   **Problemet med manuelle loops:**
#     *   `while`-løkker og håndtering af fil-læsning kan hurtigt blive uoverskueligt.
#     *   Risiko for fejl og gentagelser.
# *   **Løsning med objektorienteret programmering (OOP):**
#     *   Indkapsler data og funktionalitet i klasser.
#     *   Gør koden mere struktureret og genanvendelig.
#     *   Nem at udvide med nye funktioner uden at ændre eksisterende logik.

# %% [markdown]
# # Example: reading data in a class

# %%
filename = "files/data_1_rows.csv"
data = []
with open(filename, "r") as f:
    header = f.readline().strip()

    for line in f:
        data.append(float(line.strip()))

N = 5
print(f"First {N} rows")
for i, row in enumerate(data):
    if i > N:
        break
    print(f"  {i}: {row:.3f}")
print(f"The first row often contain the column names: {header=}")
# Out:
# First 5 rows
#   0: 0.037
#   1: -0.005
#   2: -0.026
#   3: -0.090
#   4: 0.033
#   5: 0.023
# The first row often contain the column names: header='ecg'

# %% [markdown]
# ## Exercise: Load my data 1
#
# I har nu følgende evner:
# - bruge lists og arrays
# - Bruge loops
# - læse data fra en fil til en liste
# - Printe informationer ud
#
# ### Med disse værktøjer:
# 1. Lav et program `load_my_data1.py`.
# 2. Programmet skal læse data fra filen `files/data1.csv`, som et kommatal (`float`)
# 3. Skriv de første 10 tal ud fra `data1.csv`
# 4. Find ud af for mange tal der er i `data1.csv`

# %% [markdown]
# ## Flere tal i en linje
# > Hvis `A` er en string, som indeholder to tal : 1 og 61,
#
# Dette kunne være `id=1`, og en `puls=61`.
#
#
# ```python
# A = "1,61"
# parts:list[str] = line.strip().split(",")
# id = int(parts[0])
# puls = int(parts[1])
# ```

# %% [markdown]
# ### Klasser for læsbarhed, overskuelighed, og genbrug af funktioner

# %%
class CSVDataLoader:
    def __init__(self, filename: str):
        self.filename = filename
        self.data: list | None = None
        self.header: str | None = None

    def load_data(self) -> tuple[str, list]:
        data = []
        with open(self.filename, "r") as f:
            header =f.readline().strip()  # Skip header line
            for line in f:
                data.append([float(line)])
            self.data = data
            self.header = header
        print(f"Loaded {len(data)} rows from {self.filename}")
        return header, data


data1_loader = CSVDataLoader("files/data1.csv")
header, data1 = data1_loader.load_data()
# Out:
# Loaded 454 rows from files/data1.csv

# %%
import pandas as pd
filename = "files/data_2_rows.csv"  # Her er der 2 columns
df = pd.read_csv(filename)
headers = df.columns
print(type(df.columns))  # inspect if tuples appear
print(df.columns.tolist())
df.head(5)
# Out:
# <class 'pandas.core.indexes.base.Index'>
# ['time', 'ecg']
#        time       ecg
# 0  0.000000  0.036525
# 1  0.003334 -0.004572
# 2  0.006667 -0.025637
# 3  0.010001 -0.089696
# 4  0.013334  0.033471

# %% [markdown]
# Hvis man gerne vil have lavet en colonne i en DataFrame om til en almindelig liste:

# %%
# For at få en colonne af data som fx en liste, kan man skrive følgende
column_as_list = df["ecg"].to_list()
column_as_list[:5]
# Out:
# [0.0365252590330205,
#  -0.0045717351674537,
#  -0.0256373411738366,
#  -0.0896959090111428,
#  0.0334712016541785]

# %% [markdown]
# # **Visualisering af data**
#
# For at forstå og analysere data er det vigtigt at inspicere dem visuelt.
# En af de mest effektive metoder er at bruge grafer og plots.
#
# *   **Hvorfor visualisere?**
#     *   Afslører mønstre, trends og outliers
#     *   Gør komplekse data mere intuitive
#
# *   **Typiske værktøjer**
#     *   **Matplotlib** – standardbibliotek til 2D-plot (Og det vi kommer til at benytte i dette kursus)
#     *   **Seaborn** – avanceret statistik og flot design
#     *   **Plotly** – interaktive plots

# %%
N = 600
plt.plot(data[:N], label=header)
plt.xlabel("Samples")
plt.ylabel("mV")
plt.title(f"{header.upper()} for {N} samples")
plt.show()

# %% [markdown]
# Der er mange pakker til at vise data, og arbejde med data.
# - `matplotlib` er det absolut mest udbredte

# %% [markdown]
# ### **Arbejde med flere datasæt**
#
# Når man vil håndtere flere datasæt samtidigt, fx sammenligne signaler eller have dataset-specifikke indstillinger:
#
# *   **Kompleksitet i globalt scope**
#     Variabler og indstillinger bliver hurtigt uoverskuelige.
#
# *   **Risiko for fejl**
#     Dataset-specifikke settings kan nemt blive overskrevet.
#
# *   **Manglende struktur**
#     Svært at holde styr på relationen mellem data og tilhørende konfiguration.
#
# *   **Gentagelse af kode**
#     Ofte nødvendig uden en god struktur – kan føre til vedligeholdelsesproblemer.

# %%
import numpy as np
import pandas as pd

class CSVDataLoader2:
    def __init__(self, filename: str):
        self.filename = filename
        self.data: list | None = None
        self.header: str | None = None

    def load_data(self) -> tuple[str, list]:
        data = []
        time = []
        with open(self.filename, "r") as f:
            header =f.readline().strip()  # Skip header line
            for line in f:
                parts = line.split(",")
                
                data.append(float(parts[1]))
            self.data = data
            self.header = header
        print(f"Loaded {len(data)} rows from {self.filename}")
        return header, data

dataa_samplerate = 300
datab_samplerate = 150
headera, dataa = CSVDataLoader2("files/ECG_300Hz.csv").load_data()
headerb, datab = CSVDataLoader2("files/ECG_150Hz.csv").load_data()
labela = f"ECG @ {dataa_samplerate} Hz"
labelb = f"ECG @ {datab_samplerate} Hz"
print(f"{labela:15}: {len(dataa)=}, og {dataa_samplerate=}Hz")
print(f"{labelb:15}: {len(datab)=}, og {datab_samplerate=}Hz")

plt.plot(dataa, label=labela)
plt.plot(datab, label=labelb)
plt.title(header)
plt.legend()
plt.xlabel("Samples")
plt.show()
# Out:
# Loaded 600 rows from files/ECG_300Hz.csv
# Loaded 300 rows from files/ECG_150Hz.csv
# ECG @ 300 Hz   : len(dataa)=600, og dataa_samplerate=300Hz
# ECG @ 150 Hz   : len(datab)=300, og datab_samplerate=150Hz

# %% [markdown]
# Dette er en fin løsning til at vise meget simpelt data.
#
# Hvis man rammer ind i at skal gøre dette mange gange, kan et program exploderer.
# - Svært at overskue
# - Svært at fejlfinde
# - Meget repetitiv kode
#
# For eksempel, hvorfor er det at dette plot (fra samme datasæt) ikke vise hjertecyklusser

# %% [markdown]
# ## Classes
#
# *   **Organiseret kode**
#     Samler data (attributter) og funktionalitet (metoder) i én struktur.
# *   **Genbrug og vedligeholdelse**
#     Én klasse kan bruges flere steder, og ændringer sker ét sted.
# *   **Skalerbarhed**
#     Nem at udvide med nye funktioner uden at ændre eksisterende kode.
# *   **Indkapsling**
#     Skjuler interne detaljer og giver en klar interface til brugeren.
# *   **Bedre læsbarhed**
#     Gør komplekse systemer mere overskuelige og forståelige.

# %%
class Signal:
    def __init__(self, data: list, fs: float, label: str):
        # Attributes
        self.data = data
        self.fs = fs
        self.time = np.linspace(0, len(data) / fs, len(data))
        self.label = label

    # methods
    def plot(self, ax=None):
        """Method to plot data"""
        if not ax:
            ax = plt.subplot(1, 1, 1)
        ax.plot(self.time, self.data, label=self.label)
        return ax


# Normal Function
def finalize_figure():
    """This function simply sets up current figure with the correct visual settings"""
    plt.legend()
    plt.xlabel("time [s]")
    plt.ylabel("mV")
    plt.show()


# Definer 2 sigler ud fra dataa og datab
signal_a = Signal(data=dataa, fs=dataa_samplerate, label=labela)
signal_b = Signal(data=datab, fs=datab_samplerate, label=labelb)

# Plot figurerne oven i hinanden, ved at bruge en figurehandle
ax = plt.subplot(1, 1, 1)
signal_a.plot(ax)
signal_b.plot(ax)
finalize_figure()

# %% [markdown]
# # Exercise: Person Info

# %%
df = examples.df_3(3)
df
# Out:
#                        Name         DOB  Systolic_BP  Diastolic_BP  EF_Percent
# 0  Benny Nørgaard-Henriksen  2017-11-02          132            98          58
# 1        Benedikte Simonsen  2012-10-06           93            95          56
# 2            Dr. Boris Kjær  1929-09-07          170            76          43

# %% [markdown]
# **Du ved nu**:
# - Hvordan man laver en class med en attributter via `def __init__(self, ...)`
# - hvordan man laver en method
# - Hvordan man istancierer et objekt fra en class
# - Hvordan man laver en liste
#
# **Din opgave**:
# 1. Opret et nyt Python-program ```person1.py```.
# 2. Lav en class ```PersonInfo```
#     -  med følgende attributter: ```name, dob, systolic_bp, diastolic_bp, ef_percent```
#     -  med en method `show_information`, som printer informationerne ud fra PersonInfo classen
# 3. Lav en liste af PersonInfo informationerne i tabellen ovenover (du skal bare skrive de tal her ind).
# 4. Skrive patient informationerne ud for hver patient i listen.

# %% [markdown]
# ## Answer

# %%
# Answer
class PersonInfo:
    def __init__(self, name, dob, systolic, diastolic, ef_percent):
        self.name = name
        self.dob = dob
        self.systolic = systolic
        self.diastolic = diastolic
        self.ef_percent = ef_percent

    def show_information(self):
        print(
            f"Name: {self.name}, date of birth: {self.dob}, Distolic: {self.diastolic}, ..."
        )


person1 = PersonInfo(
    name="Martin", dob="17071987", systolic=130, diastolic=80, ef_percent=55
)

person1.show_information()
# Out:
# Name: Martin, date of birth: 17071987, Distolic: 80, ...

# %% [markdown]
# ### **Indkapsling (Encapsulation)**
#
# Indkapsling betyder at samle **data (attributter)** og **metoder (funktioner)** i én enhed (en klasse) og styre adgangen til den interne tilstand for at beskytte data.
#
# **Nøglepunkter:**
# *   **Skjul intern tilstand** for at undgå direkte ændringer udefra.
# *   **Beskyttede attributter** (`_x` i Python)
#     *   Beregnet til brug internt og i underklasser.
#     *   Synlige udefra, men bør ikke ændres direkte.
# *   **Private attributter** (`__x` i Python)
#     *   Skjult for kode uden for klassen og underklasser.
# *   **Metoder**
#     *   Funktioner, der hører til klassen og arbejder på dens data.

# %%
class PersonInfo2:
    def __init__(self, name, dob, systolic, diastolic, ef_percent):
        self.__name = name
        self.__dob = dob
        self.__systolic = systolic
        self.__diastolic = diastolic
        self.__ef_percent = ef_percent

    def show_information(self):
        print(
            f"Name: {self.__name}, date of birth: {self.__dob}, Distolic: {self.__diastolic}, ..."
        )

    # Setter og Getter
    def set_diastolic(self, diastolic):
        self.__diastolic = diastolic

    def get_diastolic(self):
        return self.__diastolic


person_1 = PersonInfo2(
    name="Martin", dob="17071987", systolic=130, diastolic=80, ef_percent=55
)
person_1.diastolic = 130
person_1.show_information()


person_2 = PersonInfo2(
    name="Martin", dob="17071987", systolic=130, diastolic=80, ef_percent=55
)
# Dette kan man ikke!!!
person_2.__diastolic = (
    200  # Du tror du ændre __diastolic, den melder ikke fejl. Men det gør du IKKE!
)
person_2.show_information()
# Out:
# Name: Martin, date of birth: 17071987, Distolic: 130, ...
# Name: Martin, date of birth: 17071987, Distolic: 80, ...

# %% [markdown]
# ## Exercise: Fordele og Ulemper ved Klasser og Indkapsling
#
# Snak om hvad fordele og ulemper er ved classes og encapsulation

# %% [markdown]
# # Answer
#
# ## Fordele
# - **Modularitet:** Koden opdeles i logiske enheder → lettere vedligeholdelse.
# - **Genbrug:** Klasser kan genbruges i andre projekter.
# - **Data-beskyttelse:** Indkapsling sikrer kontrolleret adgang til data.
# - **Abstraktion:** Skjuler kompleksitet og giver et klart interface.
# - **Skalerbarhed:** Nem at udvide uden at bryde eksisterende kode.
#
# ## Ulemper
# - **Overhead:** Mere komplekst end nødvendigt for små scripts.
# - **Performance:** Kan være langsommere end procedurale løsninger.
# - **Overdesign:** Risiko for for mange klasser og abstraktioner.

# %% [markdown]
# # Informations Udtræk
#
# - Man kan benytte classes når man ønsker at arbejde med noget specifikt data.
# - Dette gør at man reducerer risikoen for at overskive variabler, og fjerner komplexitet fra brugeren.
# - Et eksempel på informations udtræk er at finde peaks i et datasæt.
#
# Herunder er der noget pseudokode, som i allerede har lavet i C på jeres ESP32.

# %% [markdown]
# ### **Pseudocode: Peak Detection**
#
# ```
# INITIALIZE:
#     thr ← initial_threshold          # main threshold for peak detection
#     record ← 0                       # current peak candidate value
#     recordt ← 0                      # index of current peak candidate
#     indecies ← []                       # list to store detected peak positions
#     t ← 0                            # sample index
#
# FOR each value in signal:
#     IF value > thr DO
#         # Above threshold: update peak candidate if higher than previous
#         IF value > record DO
#             record ← value
#             recordt ← t
#         ENDIF
#
#     ELSE DO
#         # Below threshold: check if we had a peak candidate AND signal dropped below (thr)
#         IF record > 0 DO
#             # Confirm peak and store its position
#             ADD recordt TO indecies
#             # Reset candidate
#             record ← 0
#             recordt ← 0
#         ENDIF
#
#     ENDIF
#     t ← t + 1
#
# END FOR
#
# OUTPUT indecies
# ```

# %%
class Signal2:
    def __init__(self, data: list, fs: float, label: str):
        # Attributes
        self.data: np.ndarray = np.array(data)
        self.fs = fs
        self.time: np.ndarray = np.linspace(0, len(data) / fs, len(data))
        self.label = label

    # methods
    def plot(self, ax=None):
        """Method to plot data"""
        if not ax:
            ax = plt.subplot(1, 1, 1)
        ax.plot(self.time, self.data, label=self.label)
        return ax

    def scatter(self, points: list[int], ax=None):
        """Method to plot data"""
        x = self.time[
            points
        ]  # Hvis self.time er af typen list, skal man skrive x = [self.time[i] for i in points]
        y = self.data[
            points
        ]  # Hvis self.data er af typen list, skal man skrive x = [self.data[i] for i in points]
        if not ax:
            ax = plt.subplot(1, 1, 1)
        ax.scatter(x, y, label=f"{self.label} peaks", color="r")
        return ax

    # Find peaks
    def find_peaks(self, threshold: float):
        raise NotImplementedError(
            "Implementer Pseudokoden her!"
        )  # <<== Den her kommer i til at se, når jeg vil have jer til at gøre noget.


# Definer signal a
signal2_a = Signal2(data=dataa, fs=dataa_samplerate, label=labela)
peaks_indecies_a = signal2_a.find_peaks(0.5)

# Plot figurerne oven i hinanden, ved at bruge en figurehandle
ax = plt.subplot(1, 1, 1)
signal2_a.plot(ax)
signal2_a.scatter(peaks_indecies_a, ax)
finalize_figure()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[49], line 32
#      30 # Definer signal a
#      31 signal2_a = Signal2(data=dataa, fs=dataa_samplerate, label=labela)
# ---> 32 peaks_indecies_a = signal2_a.find_peaks(0.5)
#      34 # Plot figurerne oven i hinanden, ved at bruge en figurehandle
#      35 ax = plt.subplot(1,1,1)
#
# Cell In[49], line 28, in Signal2.find_peaks(self, threshold)
#      27 def find_peaks(self, threshold:float):
# ---> 28     raise NotImplementedError("Implementer Pseudokoden!")
#
# NotImplementedError: Implementer Pseudokoden!

# %% [markdown]
# # Exercises
# *Hint:*
# - Brug debuggeren når du sidder fast, og hvis i ikke forstår hvorfor jeres resultater ikke er som forventet.
# - Brug dine medstuderende sammen med debuggeren til at identificerer problemer i jeres kode.

# %% [markdown]
# ## Exercise: Finde Hjertefrekvens og plot det over tid
#
# Du ved på nuværende tidspunkt:
# - Hvordan man importerer data fra en fil
# - Hvordan man laver en class
# - Hvordan man finder peaks i et signal
# - Hvordan man plotter data
#
# Yderligere ved du fra tidligere semestre hvordan man udregner heartrate hvis du har tidsforskellen $\Delta t$ mellem to hjerteslag
# $$
# \text{heartrate} = \frac{60}{\Delta t}
# $$
#
#
# ### Opgave:
# 1. Opret en ny Python-fil `extract_heartrate.py`
# 2. Lav en class HeartRateData, som tager en filepath og sampling frekvens ($f_s$) som input, og loader data fra filen og gemmer en i en attribute/medlemsvariabel.
# 3. Lav en metode `calculate_heartrate(threshold)`, som returnerer heartrate for alle beats i et ekg signal, samt tidspunkterne for hvert beat.
#
#    *Hints*:
#    $$\Delta t_i = (beat[i] - beat[i-1]) \cdot f_s$$
#    $$ t_i = i  / f_s $$
# 5. Analyser og plot heartrate over tid for filen `files/data_1_row.csv`, data er optaget med 300Hz

# %% [markdown]
# ## Exercise: Load Data
# **Du ved på nuværende tidspunkt:**
# * Hvordan man laver en variable, og hvordan man laver en string
# * Hvordan man loader data fra en fil
# * Hvordan man arbejder med lister
# * Hvordan man deler en string op til en liste
#
#
# Hint: Du skal altid forstå dit data. Så husk at undersøg hvad det er for noget data.
#
# **Opgave:**
# 1. Lav et program `my_loader1.py`
# 3. Lav en class `PatientInfo`,
#     - Et objekt skal indeholde informationen fra 1 linje i `files/exercise_people_small.csv`
#     - Der skal være en metode `print_information` som printer informationen for patienten
# 2. Lav en class `MyLoader` der kan læse data fra en csv fil, og gemmer data i en member variable
#     - Den skal tage en string filename som input
#     - Den skal benytte en method `load`, som ikke tager input, til at læse data og returnerer en liste af `PatientInfo` objekter.
#         - Der er 5 columns
#     - For hver kollonne, husk at konverter data til en passende datatype
# 5. Brug en instance af din `MyLoader` til at læse filen `files/exercise_people_small.csv`
# 6. Brug MyLoader, til
#
# **Hop til næste opgave, og udfør den indtil du bliver bedt om at vende tilbage hertil.**
#
# 5. Flyt step 3. og 4. fra denne opgave ind i en if statement, som ser sådan her ud
# 6. Tilføj en method `read_pandas` som benytter pandas til at læse en dataframe
#     - Load data via `pandas` package, og returner dataframe
#     - Pandas til automatisk forsøge at konverterer data til den rigtige datatype
#
#
# ```python
# class MyLoader:
#     ...
#
#
# if "__main__" == __name__:
#     # Step 3 her
#     # Step 4 her
# ```

# %% [markdown]
# ## Exercise: Show data
#
#
# **Du ved på nuværende tidspunkt:**
# * Hvordan man loader data
# * Hvordan ma arbejder med lister
# * Hvordan man laver vurderer hvilke typer af plots man vil bruge til at vise data
# * Hvordan man visualiserer data med matplotlib
#
# **Opgave:**
# 1. Lav et program `visualize data`
# 2. importer my_loader
#     - `import my_loader1`
#     - Observer at du højest sandsynligt loader data fra forrige opgave.
# 3. Gå tilbage til forrige opgave, og udfør Step 5+.
# 4. brug MyLoader til at loade data som en pandas dataframe
# 5. Lav en class `MyDataVizualizer` med en  method `scatterplot`, som laver et scatterplot af data for columns: `height_m` og `weight_kg` på X og Y aksen
#     - Plotte mænd og kvinder i hver deres farve (``)
#     - Hint: `male_df = df[df.gender == "male"]       `
#     - Du skal give plottet en title, xlabel, ylabel, og tilføje en legend, som er hhv `Female` og `Male` .

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

class MyDataLoader:
    def __init__(self, filename: str):
        self.filename = filename

    def load_data(self) -> tuple[list, list]:
        data = []
        with open(self.filename, "r") as f:
            datareader = csv.reader(f)
            headers = next(datareader)  # Første linje er headers
            data = [row for row in datareader]

            self.headers = headers
            self.data = data
            print(f"Data loaded from {self.filename}")
        return headers, data

    def load_pandas(self) -> pd.DataFrame:
        df = pd.read_csv(self.filename)
        print(f"Data loaded from {self.filename} using pandas")
        return df

class MyDataVizualizer:
    def __init__(self, data: list, headers: list):
        self.data = data
        self.headers = headers

    def plot_column(self, column_index: int, N: int = 100):
        column_data = [float(row[column_index]) for row in self.data[:N]]
        plt.plot(column_data, label=self.headers[column_index])
        plt.legend()
        plt.xlabel("Samples")
        plt.ylabel("Value")
        plt.title(f"{self.headers[column_index]} for first {N} samples")
        plt.show()

dataloader = MyDataLoader("files/data1.csv")

# %% [markdown]
# ### **Pandas DataFrame**
#
# *   Der eksterne pakker med avancerede metoder, som gør arbejdet med data lettere og mere effektivt.
# *   Et af de mest populære værktøjer er **pandas**, som er bredt anvendt inden for dataanalyse og data science.
#
# **Fordele ved pandas:**
# *   Gemmer data i en **DataFrame** – en specialiseret datatype designet til struktureret data.
# *   Understøtter nem håndtering af store datasæt, filtrering, sortering og beregninger.
# *   Integrerer godt med andre Python-biblioteker til analyse og visualisering.
#
# **Hvorfor DataFrame?**
# *   Standardformat i data science og maskinlæring.
# *   Gør komplekse operationer på data intuitive og hurtige.
